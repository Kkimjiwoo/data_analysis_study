# %% [markdown]
# **This notebook is an exercise in the [Intro to Deep Learning](https://www.kaggle.com/learn/intro-to-deep-learning) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/binary-classification).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In this exercise, you'll build a model to predict hotel cancellations with a binary classifier.

# %% [markdown]
# # Binary Classification
# - 이진 분류는 많은 기계 학습 문제
# -  "Yes"와 "No", "Dog"와 "Cat" 등과 같은 문자열로 표시

# %% [markdown]
# # Cross-Entropy (교차 엔트로피)
# - 한 확률 분포에서 다른 확률 분포로의 거리를 측정하는 방법 중 하나
# - 분류 문제에서 예측 확률 사이의 거리를 측정
# - 예측된 확률이 1.0에서 멀리 떨어질수록 Cross-Entropy 손실이 증가

# %%
# Setup plotting
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.deep_learning_intro.ex6 import *
# Out:
# /tmp/ipykernel_33/3338970720.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# First, load the *Hotel Cancellations* dataset.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('../input/dl-course-data/hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]

# %% [markdown]
# # 1) Define Model #
#
# The model we'll use this time will have both batch normalization and dropout layers. To ease reading we've broken the diagram into blocks, but you can define it layer by layer as usual.
#
# Define a model with an architecture given by this diagram:
#
# <figure style="padding: 1em;">
# <img src="https://storage.googleapis.com/kaggle-media/learn/images/V04o59Z.png" width="400" alt="Diagram of network architecture: BatchNorm, Dense, BatchNorm, Dropout, Dense, BatchNorm, Dropout, Dense.">
# <figcaption style="textalign: center; font-style: italic"><center>Diagram of a binary classifier.</center></figcaption>
# </figure>

# %%
from tensorflow import keras
from tensorflow.keras import layers

# YOUR CODE HERE: define the model given in the diagram
model = keras.Sequential([
            layers.BatchNormalization(input_shape=input_shape),
            layers.Dense(256, activation = 'relu'),
            layers.BatchNormalization(),
            layers.Dropout(0.3),
            layers.Dense(256, activation = 'relu'),
            layers.BatchNormalization(),
            layers.Dropout(0.3),
            layers.Dense(1, activation = 'sigmoid')])

# Check your answer
q_1.check()
# Out:
# Correct

# %% [markdown]
# # 2) Add Optimizer, Loss, and Metric #
#
# Now compile the model with the Adam optimizer and binary versions of the cross-entropy loss and accuracy metric.

# %%
# YOUR CODE HERE
model.compile(
    optimizer = 'adam',
    loss = 'binary_crossentropy',  # 이진 분류 모델에서 사용하는 손실 함수
    metrics =['binary_accuracy'])  # 'binary_accuracy'는 모델의 정확도를 평가하는 메트릭스

# Check your answer
q_2.check()

#
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_2.hint()
#q_2.solution()

# %% [markdown]
# Finally, run this cell to train the model and view the learning curves. It may run for around 60 to 70 epochs, which could take a minute or two.

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# Epoch 1/200
# 175/175 [==============================] - 4s 12ms/step - loss: 0.4816 - binary_accuracy: 0.7707 - val_loss: 0.4295 - val_binary_accuracy: 0.8076
# Epoch 2/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.4240 - binary_accuracy: 0.7997 - val_loss: 0.4011 - val_binary_accuracy: 0.8141
# Epoch 3/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.4104 - binary_accuracy: 0.8068 - val_loss: 0.3911 - val_binary_accuracy: 0.8187
# Epoch 4/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.4024 - binary_accuracy: 0.8122 - val_loss: 0.3877 - val_binary_accuracy: 0.8223
# Epoch 5/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3979 - binary_accuracy: 0.8135 - val_loss: 0.3819 - val_binary_accuracy: 0.8232
# Epoch 6/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3934 - binary_accuracy: 0.8166 - val_loss: 0.3798 - val_binary_accuracy: 0.8242
# Epoch 7/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3893 - binary_accuracy: 0.8180 - val_loss: 0.3775 - val_binary_accuracy: 0.8263
# Epoch 8/200
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3858 - binary_accuracy: 0.8201 - val_loss: 0.3735 - val_binary_accuracy: 0.8297
# Epoch 9/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3828 - binary_accuracy: 0.8210 - val_loss: 0.3714 - val_binary_accuracy: 0.8319
# Epoch 10/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3793 - binary_accuracy: 0.8237 - val_loss: 0.3685 - val_binary_accuracy: 0.8329
# Epoch 11/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3764 - binary_accuracy: 0.8252 - val_loss: 0.3673 - val_binary_accuracy: 0.8329
# Epoch 12/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3740 - binary_accuracy: 0.8264 - val_loss: 0.3639 - val_binary_accuracy: 0.8344
# Epoch 13/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3727 - binary_accuracy: 0.8281 - val_loss: 0.3636 - val_binary_accuracy: 0.8357
# Epoch 14/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3695 - binary_accuracy: 0.8293 - val_loss: 0.3625 - val_binary_accuracy: 0.8355
# Epoch 15/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3675 - binary_accuracy: 0.8303 - val_loss: 0.3607 - val_binary_accuracy: 0.8368
# Epoch 16/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3658 - binary_accuracy: 0.8305 - val_loss: 0.3582 - val_binary_accuracy: 0.8366
# Epoch 17/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3632 - binary_accuracy: 0.8327 - val_loss: 0.3590 - val_binary_accuracy: 0.8357
# Epoch 18/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3641 - binary_accuracy: 0.8310 - val_loss: 0.3602 - val_binary_accuracy: 0.8366
# Epoch 19/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3633 - binary_accuracy: 0.8317 - val_loss: 0.3604 - val_binary_accuracy: 0.8374
# Epoch 20/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3596 - binary_accuracy: 0.8332 - val_loss: 0.3567 - val_binary_accuracy: 0.8378
# Epoch 21/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3596 - binary_accuracy: 0.8339 - val_loss: 0.3536 - val_binary_accuracy: 0.8383
# Epoch 22/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3567 - binary_accuracy: 0.8357 - val_loss: 0.3553 - val_binary_accuracy: 0.8394
# Epoch 23/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3571 - binary_accuracy: 0.8345 - val_loss: 0.3559 - val_binary_accuracy: 0.8369
# Epoch 24/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3556 - binary_accuracy: 0.8361 - val_loss: 0.3541 - val_binary_accuracy: 0.8387
# Epoch 25/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3527 - binary_accuracy: 0.8378 - val_loss: 0.3538 - val_binary_accuracy: 0.8413
# Epoch 26/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3528 - binary_accuracy: 0.8371 - val_loss: 0.3517 - val_binary_accuracy: 0.8397
# Epoch 27/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3514 - binary_accuracy: 0.8375 - val_loss: 0.3520 - val_binary_accuracy: 0.8417
# Epoch 28/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3505 - binary_accuracy: 0.8386 - val_loss: 0.3499 - val_binary_accuracy: 0.8396
# Epoch 29/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3492 - binary_accuracy: 0.8383 - val_loss: 0.3494 - val_binary_accuracy: 0.8398
# Epoch 30/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3490 - binary_accuracy: 0.8383 - val_loss: 0.3499 - val_binary_accuracy: 0.8403
# Epoch 31/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3477 - binary_accuracy: 0.8389 - val_loss: 0.3492 - val_binary_accuracy: 0.8405
# Epoch 32/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3472 - binary_accuracy: 0.8410 - val_loss: 0.3468 - val_binary_accuracy: 0.8412
# Epoch 33/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3448 - binary_accuracy: 0.8408 - val_loss: 0.3496 - val_binary_accuracy: 0.8409
# Epoch 34/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3442 - binary_accuracy: 0.8405 - val_loss: 0.3476 - val_binary_accuracy: 0.8430
# Epoch 35/200
# 175/175 [==============================] - 2s 10ms/step - loss: 0.3434 - binary_accuracy: 0.8421 - val_loss: 0.3476 - val_binary_accuracy: 0.8434
# Epoch 36/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3415 - binary_accuracy: 0.8426 - val_loss: 0.3452 - val_binary_accuracy: 0.8442
# Epoch 37/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3415 - binary_accuracy: 0.8423 - val_loss: 0.3466 - val_binary_accuracy: 0.8429
# Epoch 38/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3409 - binary_accuracy: 0.8421 - val_loss: 0.3476 - val_binary_accuracy: 0.8431
# Epoch 39/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3403 - binary_accuracy: 0.8431 - val_loss: 0.3479 - val_binary_accuracy: 0.8432
# Epoch 40/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3390 - binary_accuracy: 0.8439 - val_loss: 0.3469 - val_binary_accuracy: 0.8434
# Epoch 41/200
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3398 - binary_accuracy: 0.8432 - val_loss: 0.3446 - val_binary_accuracy: 0.8441
# <Axes: title={'center': 'Accuracy'}>

# %% [markdown]
# # 3) Train and Evaluate #
#
#
# What do you think about the learning curves? Does it look like the model underfit or overfit? Was the cross-entropy loss a good stand-in for accuracy?

# %%
# View the solution (Run this cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
# Though we can see the training loss continuing to fall, the early stopping callback prevented any overfitting. Moreover, the accuracy rose at the same rate as the cross-entropy fell, so it appears that minimizing cross-entropy was a good stand-in. All in all, it looks like this training was a success!

# %% [markdown]
# # Conclusion #
#
# Congratulations! You've completed Kaggle's *Introduction to Deep Learning* course!
#
# With your new skills you're ready to take on more advanced applications like computer vision and sentiment classification. What would you like to do next?
#
# Why not try one of our *Getting Started* competitions?
#
# - Classify images with TPUs in [**Petals to the Metal**](https://www.kaggle.com/c/tpu-getting-started)
# - Create art with GANs in [**I'm Something of a Painter Myself**](https://www.kaggle.com/c/gan-getting-started)
# - Classify Tweets in [**Real or Not? NLP with Disaster Tweets**](https://www.kaggle.com/c/nlp-getting-started)
# - Detect contradiction and entailment in [**Contradictory, My Dear Watson**](https://www.kaggle.com/c/contradictory-my-dear-watson)
#
# Until next time, Kagglers!

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/intro-to-deep-learning/discussion) to chat with other learners.*
