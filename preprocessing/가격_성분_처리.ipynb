# %%
path = '/content/drive/MyDrive/2조self/Skin_dataset.csv'
import pandas as pd
import numpy as np

df = pd.read_csv(path, index_col = 0)
df.head()
# Out:
#                                                 name brand   price sale_price  \
# 0                            AHC 허브솔루션 위치하젤 토너 500ml   AHC  15,000     11,900
# 1   [1+1/모공케어] 유세린 더머토클린 클래리파잉 토너 더블기획 (200ml+200ml)   유세린  28,000        NaN
# 2            [1+1/수분부스터] 헉슬리 컨디셔닝 에센스 토너 프리쉐이프 300ml   헉슬리  36,000        NaN
# 3   [1+1/인사이드아웃2] 닥터지 레드 블레미쉬 클리어 수딩 토너 300ml 1+1 기획   닥터지  31,000     23,200
# 4  [1+1][구름토너] 마몽드 블루 아줄렌 클라우드 토너 150ml 기획 (+150m...   마몽드  36,000     28,800
#
#                                              picture  \
# 0  https://image.oliveyoung.co.kr/uploads/images/...
# 1  https://image.oliveyoung.co.kr/uploads/images/...
# 2  https://image.oliveyoung.co.kr/uploads/images/...
# 3  https://image.oliveyoung.co.kr/uploads/images/...
# 4  https://image.oliveyoung.co.kr/uploads/images/...
#
#                                                  url             volume  \
# 0  https://www.oliveyoung.co.kr/store/goods/getGo...              500ml
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 185 entries, 0 to 186
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        185 non-null    object
#  1   brand       185 non-null    object
#  2   price       185 non-null    object
#  3   sale_price  118 non-null    object
#  4   picture     185 non-null    object
#  5   url         185 non-null    object
#  6   volume      185 non-null    object
#  7   skin_type   185 non-null    object
#  8   ingredient  185 non-null    object
#  9   review      185 non-null    object
# dtypes: object(10)
# memory usage: 15.9+ KB

# %%
# NaN 값을 적절한 값으로 대체 (예: 0으로)
df['sale_price'] = df['sale_price'].fillna('0')

# 쉼표 제거 후 정수형으로 변환
df['sale_price'] = df['sale_price'].str.replace(',', '').astype(int)

df
# Out:
#                                                   name  brand   price  \
# 0                              AHC 허브솔루션 위치하젤 토너 500ml    AHC  15,000
# 1     [1+1/모공케어] 유세린 더머토클린 클래리파잉 토너 더블기획 (200ml+200ml)    유세린  28,000
# 2              [1+1/수분부스터] 헉슬리 컨디셔닝 에센스 토너 프리쉐이프 300ml    헉슬리  36,000
# 3     [1+1/인사이드아웃2] 닥터지 레드 블레미쉬 클리어 수딩 토너 300ml 1+1 기획    닥터지  31,000
# 4    [1+1][구름토너] 마몽드 블루 아줄렌 클라우드 토너 150ml 기획 (+150m...    마몽드  36,000
# ..                                                 ...    ...     ...
# 182                                   하다라보 고쿠쥰 로션170ml   하다라보  17,000
# 183                             하다라보 고쿠쥰 프리미엄 로션 170ml   하다라보  20,000
# 184                           헤브블루 살몬 케어링 센텔라 토너 200ml   헤브블루  41,900
# 185              헤이네이처 어성초 스킨 토너 150ml 기획(+카밍 토너패드 5매)  헤이네이처  25,000
# 186                           후시다인 더마 트러블 밸런싱 토너 150ml   후시다인  25,000
#
#      sale_price                                            picture  \
# ...

# %%
df.loc[df['sale_price'] == 0, 'sale_price'] = df['price']
# loc 사용해서, 조건에 맞는 값 사용
# Out:
# <ipython-input-94-c3086a520030>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['28,000' '36,000' '27,000' '45,000' '30,000' '21,000' '34,200' '32,000'
#  '40,000' '21,000' '24,000' '43,000' '24,000' '24,000' '45,000' '38,000'
#  '26,000' '24,000' '23,000' '15,000' '38,000' '31,000' '17,900' '9,200'
#  '13,700' '13,400' '11,800' '33,000' '24,000' '24,000' '23,000' '22,000'
#  '23,000' '25,000' '26,000' '22,000' '18,900' '29,000' '29,000' '15,000'
#  '25,000' '20,000' '15,800' '18,000' '21,600' '29,000' '29,000' '28,000'
#  '42,000' '11,500' '28,000' '43,000' '20,000' '20,000' '20,000' '20,000'
#  '20,000' '29,000' '9,000' '23,000' '34,000' '48,800' '11,200' '18,000'
#  '23,000' '25,000' '25,000']' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['sale_price'] == 0, 'sale_price'] = df['price']

# %%
df.head()
# Out:
#                                                 name brand   price sale_price  \
# 0                            AHC 허브솔루션 위치하젤 토너 500ml   AHC  15,000      11900
# 1   [1+1/모공케어] 유세린 더머토클린 클래리파잉 토너 더블기획 (200ml+200ml)   유세린  28,000     28,000
# 2            [1+1/수분부스터] 헉슬리 컨디셔닝 에센스 토너 프리쉐이프 300ml   헉슬리  36,000     36,000
# 3   [1+1/인사이드아웃2] 닥터지 레드 블레미쉬 클리어 수딩 토너 300ml 1+1 기획   닥터지  31,000      23200
# 4  [1+1][구름토너] 마몽드 블루 아줄렌 클라우드 토너 150ml 기획 (+150m...   마몽드  36,000      28800
#
#                                              picture  \
# 0  https://image.oliveyoung.co.kr/uploads/images/...
# 1  https://image.oliveyoung.co.kr/uploads/images/...
# 2  https://image.oliveyoung.co.kr/uploads/images/...
# 3  https://image.oliveyoung.co.kr/uploads/images/...
# 4  https://image.oliveyoung.co.kr/uploads/images/...
#
#                                                  url             volume  \
# 0  https://www.oliveyoung.co.kr/store/goods/getGo...              500ml
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 185 entries, 0 to 186
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        185 non-null    object
#  1   brand       185 non-null    object
#  2   price       185 non-null    object
#  3   sale_price  185 non-null    object
#  4   picture     185 non-null    object
#  5   url         185 non-null    object
#  6   volume      185 non-null    object
#  7   skin_type   185 non-null    object
#  8   ingredient  185 non-null    object
#  9   review      185 non-null    object
# dtypes: object(10)
# memory usage: 20.0+ KB

# %%
df.ingredient[1]
# Out:
# '정제수, 다이프로필렌글라이콜, 글리세린, 페녹시에탄올, 1,2-헥산다이올, 글리세릴글루코사이드, 소듐시트레이트, 시트릭애씨드, 트라이소듐이디티에이, 소듐하이알루로네이트, 코카미도프로필베타인, 데실글루코사이드, 소듐클로라이드'

# %%
def remove_non_korean(text):
    # ,를 기준으로 분리한 후 한글 문자만 남기고 나머지 문자 제거
    words = text.split(',')
    korean_words = [re.sub(r'[^가-힣\s]', '', word).strip() for word in words]  # strip으로 공백 제거
    korean_words = [word for word in korean_words if word]  # 빈 문자열 제거
    return korean_words

# 'ingredient' 열에 함수 적용하여 한글 단어 리스트로 변환
df['ingredient'] = df['ingredient'].apply(remove_non_korean)

# %%
df.ingredient[0]
# Out:
# ['정제수',
#  '버지니아풍년화수',
#  '글리세린',
#  '다이프로필렌글라이콜',
#  '에탄올',
#  '펜틸렌글라이콜',
#  '사과수',
#  '밤부사 불가리스수',
#  '소듐하이알루로네이트',
#  '은행나무잎추출물',
#  '애플민트잎추출물',
#  '부틸렌글라이콜',
#  '프로판다이올',
#  '피이지하이드로제네이티드캐스터오일',
#  '옥틸도데세스',
#  '트로메타민',
#  '카프릴릴글라이콜',
#  '헥산다이올',
#  '글리세릴카프릴레이트',
#  '폴리글루타믹애씨드',
#  '에틸헥실글리세린',
#  '카보머',
#  '다이소듐이디티에이',
#  '페녹시에탄올',
#  '향료']

# %%
df[:1]
# Out:
#                       name brand   price sale_price  \
# 0  AHC 허브솔루션 위치하젤 토너 500ml   AHC  15,000      11900
#
#                                              picture  \
# 0  https://image.oliveyoung.co.kr/uploads/images/...
#
#                                                  url volume skin_type  \
# 0  https://www.oliveyoung.co.kr/store/goods/getGo...  500ml    모든 피부용
#
#                                           ingredient  \
# 0  [정제수, 버지니아풍년화수, 글리세린, 다이프로필렌글라이콜, 에탄올, 펜틸렌글라이콜...
#
#                                               review
# 0  ['보습력이 좋지만 지성피부가 쓰기엔 살짝 무거운감이잇다고 느껴졌어요 ㅠㅠ', '유...

# %%
df.to_csv(path)
